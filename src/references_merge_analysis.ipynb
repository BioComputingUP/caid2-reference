# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset_merge_file = "../data/output/dataset_merge.tsv"

# output
figures_dir = "../data/output/references_merge_analysis"
disprot_delta_file = "../data/output/disprot_delta.tsv"

# %%
df_dataset = pd.read_csv(dataset_merge_file, sep="\t", header=[0,1], index_col=[0,1,2,3,4])
df_dataset
# Out:
#                                 reference                    \
#                                  disorder linker transition
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M        1.0    NaN        NaN
# 1      DP02342    P06837 2   L        1.0    NaN        NaN
# 2      DP02342    P06837 3   C        1.0    NaN        NaN
# 3      DP02342    P06837 4   C        1.0    NaN        NaN
# 4      DP02342    P06837 5   M        1.0    NaN        NaN
# ...                                   ...    ...        ...
# 287015 DP02544    Q04410 368 Q        1.0    NaN        NaN
# 287016 DP02544    Q04410 369 S        1.0    NaN        NaN
# 287017 DP02544    Q04410 370 S        1.0    NaN        NaN
# 287018 DP02544    Q04410 371 S        1.0    NaN        NaN
# 287019 DP02544    Q04410 372 D        1.0    NaN        NaN
#
#                                                                               \
#                                 binding nucleic acid binding binding protein
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M                   NaN     NaN             NaN
# 1      DP02342    P06837 2   L                   NaN     NaN             NaN
# 2      DP02342    P06837 3   C                   NaN     NaN             NaN
# 3      DP02342    P06837 4   C                   NaN     NaN             NaN
# 4      DP02342    P06837 5   M                   NaN     NaN             NaN
# ...                                              ...     ...             ...
# 287015 DP02544    Q04410 368 Q                   NaN     NaN             NaN
# 287016 DP02544    Q04410 369 S                   NaN     NaN             NaN
# 287017 DP02544    Q04410 370 S                   NaN     NaN             NaN
# 287018 DP02544    Q04410 371 S                   NaN     NaN             NaN
# 287019 DP02544    Q04410 372 D                   NaN     NaN             NaN
#
#                                                  disorder       ...  \
#                                 disorder_nox pdb  AIUPred APOD  ...
#        disprot_id acc    pos aa                                 ...
# 0      DP02342    P06837 1   M           1.0 NaN      1.0  0.0  ...
# 1      DP02342    P06837 2   L           1.0 NaN      1.0  0.0  ...
# 2      DP02342    P06837 3   C           1.0 NaN      1.0  0.0  ...
# 3      DP02342    P06837 4   C           1.0 NaN      1.0  0.0  ...
# 4      DP02342    P06837 5   M           1.0 NaN      1.0  0.0  ...
# ...                                      ...  ..      ...  ...  ...
# 287015 DP02544    Q04410 368 Q           1.0 NaN      1.0  1.0  ...
# 287016 DP02544    Q04410 369 S           1.0 NaN      1.0  1.0  ...
# 287017 DP02544    Q04410 370 S           1.0 NaN      1.0  0.0  ...
# 287018 DP02544    Q04410 371 S           1.0 NaN      1.0  0.0  ...
# 287019 DP02544    Q04410 372 D           1.0 NaN      1.0  0.0  ...
#
#                                      binding                                   \
#                                 MoRFchibi-mc MoRFchibi-mcl MoRFchibi-mcw OPAL
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M           NaN           1.0           1.0  1.0
# 1      DP02342    P06837 2   L           NaN           0.0           0.0  1.0
# 2      DP02342    P06837 3   C           NaN           0.0           0.0  1.0
# 3      DP02342    P06837 4   C           NaN           0.0           0.0  1.0
# 4      DP02342    P06837 5   M           NaN           0.0           0.0  1.0
# ...                                      ...           ...           ...  ...
# 287015 DP02544    Q04410 368 Q           1.0           1.0           1.0  1.0
# 287016 DP02544    Q04410 369 S           NaN           1.0           1.0  1.0
# 287017 DP02544    Q04410 370 S           NaN           1.0           1.0  1.0
# 287018 DP02544    Q04410 371 S           NaN           1.0           1.0  1.0
# 287019 DP02544    Q04410 372 D           NaN           1.0           0.0  1.0
#
#                                                                      \
#                                 ProBiPred-nucleic ProBiPred-protein
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M                0.0               1.0
# 1      DP02342    P06837 2   L                0.0               1.0
# 2      DP02342    P06837 3   C                0.0               1.0
# 3      DP02342    P06837 4   C                0.0               1.0
# 4      DP02342    P06837 5   M                1.0               1.0
# ...                                           ...               ...
# 287015 DP02544    Q04410 368 Q                0.0               0.0
# 287016 DP02544    Q04410 369 S                0.0               1.0
# 287017 DP02544    Q04410 370 S                0.0               1.0
# 287018 DP02544    Q04410 371 S                0.0               1.0
# 287019 DP02544    Q04410 372 D                0.0               1.0
#
#                                                            \
#                                 bindEmbed21IDR-idrGeneral
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M                        1.0
# 1      DP02342    P06837 2   L                        1.0
# 2      DP02342    P06837 3   C                        1.0
# 3      DP02342    P06837 4   C                        1.0
# 4      DP02342    P06837 5   M                        1.0
# ...                                                   ...
# 287015 DP02544    Q04410 368 Q                        1.0
# 287016 DP02544    Q04410 369 S                        1.0
# 287017 DP02544    Q04410 370 S                        1.0
# 287018 DP02544    Q04410 371 S                        1.0
# 287019 DP02544    Q04410 372 D                        1.0
#
#                                                        \
#                                 bindEmbed21IDR-idrNuc
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M                    1.0
# 1      DP02342    P06837 2   L                    1.0
# 2      DP02342    P06837 3   C                    1.0
# 3      DP02342    P06837 4   C                    1.0
# 4      DP02342    P06837 5   M                    1.0
# ...                                               ...
# 287015 DP02544    Q04410 368 Q                    1.0
# 287016 DP02544    Q04410 369 S                    1.0
# 287017 DP02544    Q04410 370 S                    1.0
# 287018 DP02544    Q04410 371 S                    1.0
# 287019 DP02544    Q04410 372 D                    1.0
#
#                                                            \
#                                 bindEmbed21IDR-rawGeneral
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M                        1.0
# 1      DP02342    P06837 2   L                        1.0
# 2      DP02342    P06837 3   C                        1.0
# 3      DP02342    P06837 4   C                        1.0
# 4      DP02342    P06837 5   M                        1.0
# ...                                                   ...
# 287015 DP02544    Q04410 368 Q                        1.0
# 287016 DP02544    Q04410 369 S                        1.0
# 287017 DP02544    Q04410 370 S                        1.0
# 287018 DP02544    Q04410 371 S                        1.0
# 287019 DP02544    Q04410 372 D                        1.0
#
#
#                                 bindEmbed21IDR-rawNuc
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M                    1.0
# 1      DP02342    P06837 2   L                    1.0
# 2      DP02342    P06837 3   C                    1.0
# 3      DP02342    P06837 4   C                    1.0
# 4      DP02342    P06837 5   M                    1.0
# ...                                               ...
# 287015 DP02544    Q04410 368 Q                    1.0
# 287016 DP02544    Q04410 369 S                    1.0
# 287017 DP02544    Q04410 370 S                    1.0
# 287018 DP02544    Q04410 371 S                    1.0
# 287019 DP02544    Q04410 372 D                    1.0
#
# [287020 rows x 79 columns]

# %%
df_dataset['disorder-mean'] = df_dataset.loc[:, ('disorder', )].mean(axis=1)
df_dataset['binding-mean'] = df_dataset.loc[:, ('binding', )].mean(axis=1)
df_dataset
# Out:
# /tmp/ipykernel_721282/446397907.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df_dataset['disorder-mean'] = df_dataset.loc[:, ('disorder', )].mean(axis=1)
# /tmp/ipykernel_721282/446397907.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df_dataset['binding-mean'] = df_dataset.loc[:, ('binding', )].mean(axis=1)
#                                 reference                    \
#                                  disorder linker transition
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M        1.0    NaN        NaN
# 1      DP02342    P06837 2   L        1.0    NaN        NaN
# 2      DP02342    P06837 3   C        1.0    NaN        NaN
# 3      DP02342    P06837 4   C        1.0    NaN        NaN
# 4      DP02342    P06837 5   M        1.0    NaN        NaN
# ...                                   ...    ...        ...
# 287015 DP02544    Q04410 368 Q        1.0    NaN        NaN
# 287016 DP02544    Q04410 369 S        1.0    NaN        NaN
# 287017 DP02544    Q04410 370 S        1.0    NaN        NaN
# 287018 DP02544    Q04410 371 S        1.0    NaN        NaN
# 287019 DP02544    Q04410 372 D        1.0    NaN        NaN
#
#                                                                               \
#                                 binding nucleic acid binding binding protein
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M                   NaN     NaN             NaN
# 1      DP02342    P06837 2   L                   NaN     NaN             NaN
# 2      DP02342    P06837 3   C                   NaN     NaN             NaN
# 3      DP02342    P06837 4   C                   NaN     NaN             NaN
# 4      DP02342    P06837 5   M                   NaN     NaN             NaN
# ...                                              ...     ...             ...
# 287015 DP02544    Q04410 368 Q                   NaN     NaN             NaN
# 287016 DP02544    Q04410 369 S                   NaN     NaN             NaN
# 287017 DP02544    Q04410 370 S                   NaN     NaN             NaN
# 287018 DP02544    Q04410 371 S                   NaN     NaN             NaN
# 287019 DP02544    Q04410 372 D                   NaN     NaN             NaN
#
#                                                  disorder       ...  \
#                                 disorder_nox pdb  AIUPred APOD  ...
#        disprot_id acc    pos aa                                 ...
# 0      DP02342    P06837 1   M           1.0 NaN      1.0  0.0  ...
# 1      DP02342    P06837 2   L           1.0 NaN      1.0  0.0  ...
# 2      DP02342    P06837 3   C           1.0 NaN      1.0  0.0  ...
# 3      DP02342    P06837 4   C           1.0 NaN      1.0  0.0  ...
# 4      DP02342    P06837 5   M           1.0 NaN      1.0  0.0  ...
# ...                                      ...  ..      ...  ...  ...
# 287015 DP02544    Q04410 368 Q           1.0 NaN      1.0  1.0  ...
# 287016 DP02544    Q04410 369 S           1.0 NaN      1.0  1.0  ...
# 287017 DP02544    Q04410 370 S           1.0 NaN      1.0  0.0  ...
# 287018 DP02544    Q04410 371 S           1.0 NaN      1.0  0.0  ...
# 287019 DP02544    Q04410 372 D           1.0 NaN      1.0  0.0  ...
#
#                                       binding                         \
#                                 MoRFchibi-mcw OPAL ProBiPred-nucleic
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M            1.0  1.0               0.0
# 1      DP02342    P06837 2   L            0.0  1.0               0.0
# 2      DP02342    P06837 3   C            0.0  1.0               0.0
# 3      DP02342    P06837 4   C            0.0  1.0               0.0
# 4      DP02342    P06837 5   M            0.0  1.0               1.0
# ...                                       ...  ...               ...
# 287015 DP02544    Q04410 368 Q            1.0  1.0               0.0
# 287016 DP02544    Q04410 369 S            1.0  1.0               0.0
# 287017 DP02544    Q04410 370 S            1.0  1.0               0.0
# 287018 DP02544    Q04410 371 S            1.0  1.0               0.0
# 287019 DP02544    Q04410 372 D            0.0  1.0               0.0
#
#                                                                              \
#                                 ProBiPred-protein bindEmbed21IDR-idrGeneral
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M                1.0                       1.0
# 1      DP02342    P06837 2   L                1.0                       1.0
# 2      DP02342    P06837 3   C                1.0                       1.0
# 3      DP02342    P06837 4   C                1.0                       1.0
# 4      DP02342    P06837 5   M                1.0                       1.0
# ...                                           ...                       ...
# 287015 DP02544    Q04410 368 Q                0.0                       1.0
# 287016 DP02544    Q04410 369 S                1.0                       1.0
# 287017 DP02544    Q04410 370 S                1.0                       1.0
# 287018 DP02544    Q04410 371 S                1.0                       1.0
# 287019 DP02544    Q04410 372 D                1.0                       1.0
#
#                                                        \
#                                 bindEmbed21IDR-idrNuc
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M                    1.0
# 1      DP02342    P06837 2   L                    1.0
# 2      DP02342    P06837 3   C                    1.0
# 3      DP02342    P06837 4   C                    1.0
# 4      DP02342    P06837 5   M                    1.0
# ...                                               ...
# 287015 DP02544    Q04410 368 Q                    1.0
# 287016 DP02544    Q04410 369 S                    1.0
# 287017 DP02544    Q04410 370 S                    1.0
# 287018 DP02544    Q04410 371 S                    1.0
# 287019 DP02544    Q04410 372 D                    1.0
#
#                                                            \
#                                 bindEmbed21IDR-rawGeneral
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M                        1.0
# 1      DP02342    P06837 2   L                        1.0
# 2      DP02342    P06837 3   C                        1.0
# 3      DP02342    P06837 4   C                        1.0
# 4      DP02342    P06837 5   M                        1.0
# ...                                                   ...
# 287015 DP02544    Q04410 368 Q                        1.0
# 287016 DP02544    Q04410 369 S                        1.0
# 287017 DP02544    Q04410 370 S                        1.0
# 287018 DP02544    Q04410 371 S                        1.0
# 287019 DP02544    Q04410 372 D                        1.0
#
#                                                       disorder-mean  \
#                                 bindEmbed21IDR-rawNuc
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M                    1.0      0.850436
# 1      DP02342    P06837 2   L                    1.0      0.850179
# 2      DP02342    P06837 3   C                    1.0      0.875410
# 3      DP02342    P06837 4   C                    1.0      0.876256
# 4      DP02342    P06837 5   M                    1.0      0.899079
# ...                                               ...           ...
# 287015 DP02544    Q04410 368 Q                    1.0      0.985975
# 287016 DP02544    Q04410 369 S                    1.0      0.984300
# 287017 DP02544    Q04410 370 S                    1.0      0.961775
# 287018 DP02544    Q04410 371 S                    1.0      0.959625
# 287019 DP02544    Q04410 372 D                    1.0      0.960487
#
#                                 binding-mean
#
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M      0.929567
# 1      DP02342    P06837 2   L      0.862967
# 2      DP02342    P06837 3   C      0.863100
# 3      DP02342    P06837 4   C      0.895867
# 4      DP02342    P06837 5   M      0.929267
# ...                                      ...
# 287015 DP02544    Q04410 368 Q      0.863935
# 287016 DP02544    Q04410 369 S      0.926967
# 287017 DP02544    Q04410 370 S      0.925533
# 287018 DP02544    Q04410 371 S      0.893567
# 287019 DP02544    Q04410 372 D      0.859167
#
# [287020 rows x 81 columns]

# %%
# Modify reference values for the figure offset
# df_dataset['af-plddt'] = 1 - df_dataset[('alphafold', 'af-disorder')]
df_dataset.loc[df_dataset[('reference', 'disorder')] == 1, 'disorder-y'] = 1.15
df_dataset.loc[df_dataset[('reference', 'binding')] == 1, 'binding-y'] = 1.1
df_dataset.loc[df_dataset[('reference', 'pdb')] == 1, 'pdb'] = 1.05
df_dataset
# Out:
#                                 reference                    \
#                                  disorder linker transition
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M        1.0    NaN        NaN
# 1      DP02342    P06837 2   L        1.0    NaN        NaN
# 2      DP02342    P06837 3   C        1.0    NaN        NaN
# 3      DP02342    P06837 4   C        1.0    NaN        NaN
# 4      DP02342    P06837 5   M        1.0    NaN        NaN
# ...                                   ...    ...        ...
# 287015 DP02544    Q04410 368 Q        1.0    NaN        NaN
# 287016 DP02544    Q04410 369 S        1.0    NaN        NaN
# 287017 DP02544    Q04410 370 S        1.0    NaN        NaN
# 287018 DP02544    Q04410 371 S        1.0    NaN        NaN
# 287019 DP02544    Q04410 372 D        1.0    NaN        NaN
#
#                                                                               \
#                                 binding nucleic acid binding binding protein
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M                   NaN     NaN             NaN
# 1      DP02342    P06837 2   L                   NaN     NaN             NaN
# 2      DP02342    P06837 3   C                   NaN     NaN             NaN
# 3      DP02342    P06837 4   C                   NaN     NaN             NaN
# 4      DP02342    P06837 5   M                   NaN     NaN             NaN
# ...                                              ...     ...             ...
# 287015 DP02544    Q04410 368 Q                   NaN     NaN             NaN
# 287016 DP02544    Q04410 369 S                   NaN     NaN             NaN
# 287017 DP02544    Q04410 370 S                   NaN     NaN             NaN
# 287018 DP02544    Q04410 371 S                   NaN     NaN             NaN
# 287019 DP02544    Q04410 372 D                   NaN     NaN             NaN
#
#                                                  disorder       ...  \
#                                 disorder_nox pdb  AIUPred APOD  ...
#        disprot_id acc    pos aa                                 ...
# 0      DP02342    P06837 1   M           1.0 NaN      1.0  0.0  ...
# 1      DP02342    P06837 2   L           1.0 NaN      1.0  0.0  ...
# 2      DP02342    P06837 3   C           1.0 NaN      1.0  0.0  ...
# 3      DP02342    P06837 4   C           1.0 NaN      1.0  0.0  ...
# 4      DP02342    P06837 5   M           1.0 NaN      1.0  0.0  ...
# ...                                      ...  ..      ...  ...  ...
# 287015 DP02544    Q04410 368 Q           1.0 NaN      1.0  1.0  ...
# 287016 DP02544    Q04410 369 S           1.0 NaN      1.0  1.0  ...
# 287017 DP02544    Q04410 370 S           1.0 NaN      1.0  0.0  ...
# 287018 DP02544    Q04410 371 S           1.0 NaN      1.0  0.0  ...
# 287019 DP02544    Q04410 372 D           1.0 NaN      1.0  0.0  ...
#
#                                           binding                            \
#                                 ProBiPred-protein bindEmbed21IDR-idrGeneral
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M                1.0                       1.0
# 1      DP02342    P06837 2   L                1.0                       1.0
# 2      DP02342    P06837 3   C                1.0                       1.0
# 3      DP02342    P06837 4   C                1.0                       1.0
# 4      DP02342    P06837 5   M                1.0                       1.0
# ...                                           ...                       ...
# 287015 DP02544    Q04410 368 Q                0.0                       1.0
# 287016 DP02544    Q04410 369 S                1.0                       1.0
# 287017 DP02544    Q04410 370 S                1.0                       1.0
# 287018 DP02544    Q04410 371 S                1.0                       1.0
# 287019 DP02544    Q04410 372 D                1.0                       1.0
#
#                                                        \
#                                 bindEmbed21IDR-idrNuc
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M                    1.0
# 1      DP02342    P06837 2   L                    1.0
# 2      DP02342    P06837 3   C                    1.0
# 3      DP02342    P06837 4   C                    1.0
# 4      DP02342    P06837 5   M                    1.0
# ...                                               ...
# 287015 DP02544    Q04410 368 Q                    1.0
# 287016 DP02544    Q04410 369 S                    1.0
# 287017 DP02544    Q04410 370 S                    1.0
# 287018 DP02544    Q04410 371 S                    1.0
# 287019 DP02544    Q04410 372 D                    1.0
#
#                                                            \
#                                 bindEmbed21IDR-rawGeneral
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M                        1.0
# 1      DP02342    P06837 2   L                        1.0
# 2      DP02342    P06837 3   C                        1.0
# 3      DP02342    P06837 4   C                        1.0
# 4      DP02342    P06837 5   M                        1.0
# ...                                                   ...
# 287015 DP02544    Q04410 368 Q                        1.0
# 287016 DP02544    Q04410 369 S                        1.0
# 287017 DP02544    Q04410 370 S                        1.0
# 287018 DP02544    Q04410 371 S                        1.0
# 287019 DP02544    Q04410 372 D                        1.0
#
#                                                       disorder-mean  \
#                                 bindEmbed21IDR-rawNuc
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M                    1.0      0.850436
# 1      DP02342    P06837 2   L                    1.0      0.850179
# 2      DP02342    P06837 3   C                    1.0      0.875410
# 3      DP02342    P06837 4   C                    1.0      0.876256
# 4      DP02342    P06837 5   M                    1.0      0.899079
# ...                                               ...           ...
# 287015 DP02544    Q04410 368 Q                    1.0      0.985975
# 287016 DP02544    Q04410 369 S                    1.0      0.984300
# 287017 DP02544    Q04410 370 S                    1.0      0.961775
# 287018 DP02544    Q04410 371 S                    1.0      0.959625
# 287019 DP02544    Q04410 372 D                    1.0      0.960487
#
#                                 binding-mean disorder-y binding-y pdb
#
#        disprot_id acc    pos aa
# 0      DP02342    P06837 1   M      0.929567       1.15       NaN NaN
# 1      DP02342    P06837 2   L      0.862967       1.15       NaN NaN
# 2      DP02342    P06837 3   C      0.863100       1.15       NaN NaN
# 3      DP02342    P06837 4   C      0.895867       1.15       NaN NaN
# 4      DP02342    P06837 5   M      0.929267       1.15       NaN NaN
# ...                                      ...        ...       ...  ..
# 287015 DP02544    Q04410 368 Q      0.863935       1.15       NaN NaN
# 287016 DP02544    Q04410 369 S      0.926967       1.15       NaN NaN
# 287017 DP02544    Q04410 370 S      0.925533       1.15       NaN NaN
# 287018 DP02544    Q04410 371 S      0.893567       1.15       NaN NaN
# 287019 DP02544    Q04410 372 D      0.859167       1.15       NaN NaN
#
# [287020 rows x 84 columns]

# %%
# Generate all the figures
"""
orange (1.0, 0.4980392156862745, 0.054901960784313725)
red (0.8392156862745098, 0.15294117647058825, 0.1568627450980392)
blue (0.12156862745098039, 0.4666666666666667, 0.7058823529411765)
green (0.17254901960784313, 0.6274509803921569, 0.17254901960784313)
violet (0.5490196078431373, 0.33725490196078434, 0.29411764705882354)
violet2 (0.8901960784313725, 0.4666666666666667, 0.7607843137254902)
gray (0.4980392156862745, 0.4980392156862745, 0.4980392156862745)
yellow (0.7372549019607844, 0.7411764705882353, 0.13333333333333333)
cyan (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)
"""
colors_reference = [(1.0, 0.4980392156862745, 0.054901960784313725),
            (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
            (0.12156862745098039, 0.4666666666666667, 0.7058823529411765)]

colors_pred = [(1.0, 0.4980392156862745, 0.054901960784313725),
            (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
            (0.4980392156862745, 0.4980392156862745, 0.4980392156862745)]

for name, df_g in df_dataset.groupby(['disprot_id', 'acc']):
    df_g.reset_index(level='pos', inplace=True)

    fig, axes = plt.subplots(2,1, figsize=(30,10), gridspec_kw={'height_ratios': [2, 6]})
    plt.subplots_adjust(wspace=0, hspace=0)

    df_g.loc[:, [('pos', ''), ('disorder-y', ''), ('binding-y', ''), ('pdb', '')]].plot(
        x='pos', ylim=(0,1.4), grid=True, ax=axes[0], fontsize=18, color=colors_reference, linewidth=6)

    df_g.loc[:, [('pos', ''), ('disorder-mean', ''), ('binding-mean', ''), ('disorder', 'AlphaFold-disorder')]].plot(
        x='pos', ylim=(0,1.4), grid=True, ax=axes[1], fontsize=18, color=colors_pred, linewidth=3)

    axes[1].hlines(0.331, xmin=1, xmax=df_g['pos'].max(), lw=1, linestyle='-', color='black')

    axes[0].set_title(" - ".join(name), fontdict={'fontsize':18})
    axes[0].set_ylim(1, 1.4)
    axes[0].set_xlim(1, df_g['pos'].max())
    axes[0].axis('off')
    h,_ = axes[0].get_legend_handles_labels()
    axes[0].legend(h, ['Disorder - DisProt', 'Binding - DisProt', 'PDB observed'],
                   prop={'size': 18}, loc='lower left', bbox_to_anchor=(-0.007, 0.5), ncol=3)

    axes[1].set_ylim(0, 1.1)
    axes[1].set_xlim(1, df_g['pos'].max())
    axes[1].xaxis.label.set_visible(False)
    h,_ = axes[1].get_legend_handles_labels()
    axes[1].legend(h, ['Disorder prediction', 'Binding prediction', 'AlphaFold-disorder'],
                   prop={'size': 18}, loc='lower left', bbox_to_anchor=(0.55, 1.17), ncol=3)

    fig.savefig("{}/{}.png".format(figures_dir, "_".join(name)), bbox_inches='tight')
    plt.close(fig)
    # break

# %%
# Find cases where Disprot strongly disagree with AlphaFold
df_ = df_dataset.groupby(['disprot_id', 'acc']).apply(lambda x: ((x['disorder-y'].sum() - x[('disorder', 'AlphaFold-disorder')].sum()) * 100 / x.index.get_level_values(3).max(), (x['binding-y'].sum() - x[('binding-mean', '')].sum()) * 100 / x.index.get_level_values(3).max())).reset_index(name='delta')
df_[['delta-disorder', 'delta-binding']] = pd.DataFrame(df_.delta.tolist(), index= df_.index)
df_.drop(columns='delta', inplace=True)
df_.sort_values(['delta-disorder', 'delta-binding'], inplace=True)
df_.to_csv(disprot_delta_file, sep="\t", index=False)
df_
# Out:
#     disprot_id       acc  delta-disorder  delta-binding
# 6      DP02393    Q8IZD2      -55.210118     -66.591855
# 84     DP02891    Q9V727      -52.984661     -71.550553
# 161    DP03266    Q9M658      -50.495052     -61.307513
# 96     DP02953    P08572      -50.429439     -53.601890
# 155    DP03227    P15205      -48.625437     -71.706694
# ..         ...       ...             ...            ...
# 305    DP03664    P0C1C6      115.000000     -90.246379
# 107    DP03001    O55777      115.000000      23.054133
# 106    DP03000    Q997F2      115.000000      28.500184
# 188    DP03408  Q9BXH1-2      115.000000     -69.870141
# 184    DP03403  Q8WXS3-1      115.000000     -89.651706
#
# [348 rows x 4 columns]
